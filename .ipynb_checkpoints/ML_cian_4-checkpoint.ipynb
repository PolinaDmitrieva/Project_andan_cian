# %% [markdown]
# # Машинное обучение

# %% [markdown]
# План :
# * Линейная регрессия
# * Случайный лес
# * Градиентный бустинг

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Загрузим наши обработанные данные и разделим признаки и целевую метку. Затем разделим на тестовую и обучающую выборки.

# %%
df = pd.read_csv('data_without_miss.csv')

X = df.iloc[:,:-2]
y = df['Цена']

# %%
X.isnull().sum()
# Out:
# Округ                       0
# Ближайшая станция метро    10
# Время до метро              0
# Метро рядом                 0
# Застройщик                 94
# ЖК                         17
# Класс                      94
# Тип квартиры                0
# Этаж                        0
# Этажей в доме               0
# Отделка                     0
# Количество комнат           0
# Площадь квартиры            0
# Жилая площадь               0
# Площадь кухни               0
# Тип дома                   94
# Парковка                   94
# Год сдачи                   0
# dtype: int64

# %% [markdown]
# В пункте с EDA пропуски в категориальных признаках мы хаменяли пустыми строками, сейчас они опять рассматриваются как пропуски, поэтому давайте снова заполним их пустыми строками

# %%
categorical_features = X.dtypes[X.dtypes == "object"].index

X[categorical_features] = X[categorical_features].fillna('')

# %%
X.isnull().sum()
# Out:
# Округ                      0
# Ближайшая станция метро    0
# Время до метро             0
# Метро рядом                0
# Застройщик                 0
# ЖК                         0
# Класс                      0
# Тип квартиры               0
# Этаж                       0
# Этажей в доме              0
# Отделка                    0
# Количество комнат          0
# Площадь квартиры           0
# Жилая площадь              0
# Площадь кухни              0
# Тип дома                   0
# Парковка                   0
# Год сдачи                  0
# dtype: int64

# %% [markdown]
# Среди признаков есть не особо информативные, например, ЖК, в котором находится квартира, так как влияние этого признака легко заменить классом этого ЖК, что намного сильнее влияет на целевую переменную

# %%
X = X.drop(columns = 'ЖК')

# %%
X.head()
# Out:
#   Округ Ближайшая станция метро  Время до метро  Метро рядом  \
# 0  СВАО            Марьина роща            17.0            2
# 1  СЗАО             Трикотажная             4.0            3
# 2   САО           Тимирязевская             3.0            3
# 3   ЗАО                    Фили             5.0            3
# 4   САО             Белорусская             4.0            3
#
#          Застройщик    Класс Тип квартиры  Этаж  Этажей в доме       Отделка  \
# 0   Компания Пионер  Премиум     квартира   5.0           22.0   Без отделки
# 1       СК Резиденс   Бизнес     квартира   2.0           26.0    Неизвестно
# 2          MR Group  Премиум     квартира   2.0           36.0      Чистовая
# 3  Аеон Девелопмент  Премиум     квартира   2.0           45.0   Без отделки
# 4          MR Group  Премиум  апартаменты   2.0           16.0  Предчистовая
#
#    Количество комнат  Площадь квартиры  Жилая площадь  Площадь кухни  \
# 0                1.0             32.20      20.333629      11.724697
# 1                1.0             48.06      20.333629      11.724697
# 2                1.0             37.62      12.800000       3.100000
# 3                1.0             42.80      20.333629      11.724697
# 4                1.0             47.90      20.333629      11.724697
#
#               Тип дома             Парковка  Год сдачи
# 0           Монолитный            Подземная     2025.0
# 1  Монолитно-кирпичный  Подземная, гостевая     2023.0
# 2           Монолитный  Подземная, гостевая     2025.0
# 3  Монолитно-кирпичный            Подземная     2026.0
# 4  Монолитно-кирпичный  Подземная, гостевая     2023.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)

# %% [markdown]
# ## `Линейная регрессия`

# %% [markdown]
# У нас достаточно много категориальных данных, закодируем их с помощью `OneHotEncoder`, а вещественные признаки стандартизируем с помощью `StandardScaler`:

# %%
X.isnull().sum()
# Out:
# Округ                      0
# Ближайшая станция метро    0
# Время до метро             0
# Метро рядом                0
# Застройщик                 0
# Класс                      0
# Тип квартиры               0
# Этаж                       0
# Этажей в доме              0
# Отделка                    0
# Количество комнат          0
# Площадь квартиры           0
# Жилая площадь              0
# Площадь кухни              0
# Тип дома                   0
# Парковка                   0
# Год сдачи                  0
# dtype: int64

# %%
numeric_features = X.select_dtypes([np.number]).columns
categorical_features = X.dtypes[X.dtypes == "object"].index

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer


column_transformer = ColumnTransformer([
    ('scaling', StandardScaler(), numeric_features),    
    ('ohe', OneHotEncoder(handle_unknown="ignore", drop="first",
                         min_frequency=0.001), categorical_features)
])

X_train_transf = column_transformer.fit_transform(X_train)
X_test_transf = column_transformer.transform(X_train)

print("Size before OneHot:", X_train.shape)
print("Size after OneHot:", X_train_transf.shape)
# Out:
# Size before OneHot: (825, 17)
# Size after OneHot: (825, 228)

# %% [markdown]
# Количество признаков после кодирования увеличилось больше, чем в 10 раз, что очень плохо скажется на качестве модели и скорее всего приведет к ее переобучению. Попроубем побороть эту проблему с помощью __$L_1$ - регуляризации__, у которой есть очень полезное для нас свйство - зануление наименее важных признаков

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

lasso_pipeline = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso())
])

model = lasso_pipeline.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
print("Train MSE = %.4f" % mean_squared_error(y_train, y_train_pred))
# Out:
# Test MSE = 6638187792432.3848
# Train MSE = 2156934755472.8640

# %% [markdown]
# Посмотрим сколько коэффициентов занулилось

# %%
np.sum(lasso_pipeline.steps[-1][-1].coef_==0)
# Out:
# 0

# %% [markdown]
# `Во - первых`, ошибка на тесте намного выше, чем на на тренировочных данных, что свидетельствует о переобучении, `во - вторых`
# , ни один из коэффициент не равен нулю
# Давайте попробуем улучшить качество, подобрав коэффициент регуляризации с помощью `GridSearchCV`

# %%
from sklearn.model_selection import GridSearchCV

alphas = np.logspace(-2, 50, 25)
searcher = GridSearchCV(lasso_pipeline, [{"regression__alpha": alphas}],
                        scoring="neg_root_mean_squared_error", cv=10, n_jobs=-1)
searcher.fit(X_train, y_train)

best_alpha = searcher.best_params_["regression__alpha"]
# Out:
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 737238599725762.4, tolerance: 4560362994641.052
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 777428922691358.5, tolerance: 4764039434232.562
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 743320083807037.2, tolerance: 4547311010548.52
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 778532345871871.6, tolerance: 4650509972788.802
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 796613939034188.4, tolerance: 4735358141467.346
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 766311317299078.4, tolerance: 4809907014184.2705
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 816665738514028.5, tolerance: 4696588543990.153
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 704565782160846.5, tolerance: 4577752195899.915
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 699164105077870.1, tolerance: 4696588543990.153
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 685575481699177.4, tolerance: 4547311010548.52
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 624486429049215.5, tolerance: 4577752195899.915
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 620743642175423.1, tolerance: 4560362994641.052
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 704952469127970.5, tolerance: 4764039434232.562
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 749717695943849.4, tolerance: 4649858715975.069
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 804640891288846.0, tolerance: 4616482979310.873
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 740663295756733.1, tolerance: 4650509972788.802
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 709562434372498.0, tolerance: 4735358141467.346
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 597568986489424.0, tolerance: 4616482979310.873
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 625143165781715.8, tolerance: 4809907014184.2705
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54434789190403.5, tolerance: 4560362994641.052
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 679282411922811.0, tolerance: 4649858715975.069
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7374648642817.5, tolerance: 4577752195899.915
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34580390104708.75, tolerance: 4547311010548.52
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98708523459824.75, tolerance: 4696588543990.153
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 142060891820389.62, tolerance: 4616482979310.873
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78133740052008.62, tolerance: 4650509972788.802
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26363036302712.5, tolerance: 4649858715975.069
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:592: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39886209858185.25, tolerance: 4809907014184.2705
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2, 5] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/polinadmitrieva/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# Выведем наилучший коэффициент регуляризации:

# %%
best_alpha
# Out:
# 215.44346900318823

# %%
lasso_pipeline_best = Pipeline(steps=[
    ('ohe_and_scaling', column_transformer),
    ('regression', Lasso(best_alpha))
])

model_best = lasso_pipeline_best.fit(X_train, y_train)

y_pred = model_best.predict(X_test)
y_train_pred = model_best.predict(X_train)

print("Test MSE = %.4f" % mean_squared_error(y_test, y_pred))
print("Train MSE = %.4f" % mean_squared_error(y_train, y_train_pred))
# Out:
# Test MSE = 6520715696724.0127
# Train MSE = 2173386263076.4314

# %% [markdown]
# С учетом регуляризации ошибка уменьшилась на обеих выборках, но все равно ошибка на тесте намного больше,чем на трейне. Таким образом линейная модель вряд ли может считаться подходящей моделью для наших данных

# %% [markdown]
# ## `Случайный лес`

# %% [markdown]
# Для начала обучим случайный лес на дефолтных параметрах, как и в предыдущем пункте

# %%
X_train
# Out:
#                      Округ Ближайшая станция метро  Время до метро  \
# 306                    САО                    Марк             4.0
# 420                    САО                Окружная            12.0
# 60                     ВАО  Преображенская площадь             6.0
# 458                    ЦАО                Шелепиха            13.0
# 92                     ЦАО        Электрозаводская            15.0
# ...                    ...                     ...             ...
# 466                   ЮВАО                Дубровка             4.0
# 121                   СЗАО               Стрешнево            11.0
# 1044                  СВАО               Бутырская             8.0
# 1095  НАО (Новомосковский)                Ольховая            17.0
# 860   НАО (Новомосковский)             Филатов Луг             5.0
#
#       Метро рядом     Застройщик    Класс Тип квартиры  Этаж  Этажей в доме  \
# 306             3            ПИК  Комфорт       Студия  32.0           33.0
# 420             3            ПИК  Комфорт     квартира   2.0           21.0
# 60              3                          апартаменты   3.0            4.0
# 458             2        КОРТРОС   Бизнес     квартира  19.0           51.0
# 92              2    Level Group   Бизнес     квартира   3.0           17.0
# ...           ...            ...      ...          ...   ...            ...
# 466             3       MR Group   Бизнес  апартаменты   8.0            8.0
# 121             2       Мангазея   Бизнес     квартира  12.0           21.0
# 1044            3            ПИК  Комфорт       Студия  25.0           33.0
# 1095            3  Группа Родина   Бизнес     квартира  12.0           13.0
# 860             3            ПИК  Комфорт       Студия  12.0           14.0
#
#            Отделка  Количество комнат  Площадь квартиры  Жилая площадь  \
# 306     Неизвестно                1.0             25.52      12.200000
# 420       Чистовая                2.0             60.90      21.900000
# 60        Чистовая                3.0             86.20      20.333629
# 458    Без отделки                1.0             43.01      20.333629
# 92     Без отделки                3.0             73.90      28.300000
# ...            ...                ...               ...            ...
# 466   Предчистовая                2.0             98.20      32.700000
# 121    Без отделки                1.0             48.60      17.200000
# 1044      Чистовая                1.0             25.40      12.400000
# 1095   Без отделки                1.0             36.90      12.200000
# 860       Чистовая                1.0             19.90       9.800000
#
#       Площадь кухни                         Тип дома  \
# 306        6.500000                       Монолитный
# 420       15.800000                        Панельный
# 60        11.724697
# 458       11.724697              Монолитно-кирпичный
# 92        25.800000                       Монолитный
# ...             ...                              ...
# 466       42.200000  Монолитно-кирпичный, монолитный
# 121       15.900000  Монолитно-кирпичный, монолитный
# 1044       6.400000            Панельный, монолитный
# 1095      11.400000              Монолитно-кирпичный
# 860        5.000000                       Монолитный
#
#                                 Парковка  Год сдачи
# 306                  Подземная, гостевая     2023.0
# 420   Отдельная многоуровневая, гостевая     2023.0
# 60                                           2022.0
# 458                  Подземная, гостевая     2023.0
# 92                             Подземная     2025.0
# ...                                  ...        ...
# 466                  Подземная, гостевая     2022.0
# 121                  Подземная, гостевая     2023.0
# 1044                 Подземная, гостевая     2025.0
# 1095                 Подземная, гостевая     2023.0
# 860                  Подземная, гостевая     2025.0
#
# [825 rows x 17 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)

print(f"MSE on train set: {mean_squared_error(y_train, rf.predict(X_train)):.2f}")
print(f"MSE on train set: {mean_squared_error(y_test, rf.predict(X_test)):.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 4
#       1 from sklearn.ensemble import RandomForestRegressor
#       3 rf = RandomForestRegressor()
# ----> 4 rf.fit(X_train, y_train)
#       6 print(f"MSE on train set: {mean_squared_error(y_train, rf.predict(X_train)):.2f}")
#       7 print(f"MSE on train set: {mean_squared_error(y_test, rf.predict(X_test)):.2f}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:345, in BaseForest.fit(self, X, y, sample_weight)
#     343 if issparse(y):
#     344     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345 X, y = self._validate_data(
#     346     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347 )
#     348 if sample_weight is not None:
#     349     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:584, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582         y = check_array(y, input_name="y", **check_y_params)
#     583     else:
# --> 584         X, y = check_X_y(X, y, **check_params)
#     585     out = X, y
#     587 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:1993, in NDFrame.__array__(self, dtype)
#    1992 def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'САО'
