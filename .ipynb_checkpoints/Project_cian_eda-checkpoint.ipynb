# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn")

# %% [markdown]
# ### Дополнительная литература
#
# 1. `https://www.helenkapatsa.ru/razvedochnyy-analiz-dannykh-chast-1/`
#
# 2. `https://www.helenkapatsa.ru/razvedochnyy-analiz-dannykh-chast-2/`

# %% [markdown]
# ## Описание данных
#
#  - `Округ` - округ Москвы, в котором расположена квартира
#
#
#  - `Ближайшая станция метро` - ближайшая станция метро, рядом с которой расположен ЖК
#  - `Время до метро` - кратчайшее время пешком до метро
#  - `Метро рядом` - количество станций метро расположенных в пешей доступности
#  - `Застройщик` - застройщик дома
#  - `ЖК` - жилой комплекс, в котором расположена квартира
#  - `Класс` - класс жилья
#  - `Тип квартиры` - тип жилплощади (квартира, апартаменты, студия)
#  - `Этаж` - этаж, на котором расположена квартира
#  - `Этажей в доме` - количеств этажей в доме
#  - `Отделка` - тип отделки квартиры (без отделки, чистовая, предчитовая и тд)
#  - `Количество комнат` - количество комнат в квартире
#  - `Площадь квартиры` - суммарная площадь квартиры
#  - `Жилая площадь` - жилая площадь из всей площади квартиры
#  - `Площадь кухни` - площадь кухни
#  - `Тип дома` - из чего сделан дом
#  - `Парковка` - наличие и вид парковки
#  - `Год сдачи` - когда был сдан или будет
#  - `Цена` - цена квартиры

# %% [markdown]
# ## Анализ EDA

# %% [markdown]
# Для начала посмотрим на парсированные нами данные:

# %%
df = pd.read_csv('cian_data.csv')
df.head(10)
# Out:
#    Округ Ближайшая станция метро  Время до метро  Метро рядом  \
# 0   СВАО            Марьина роща            17.0            2
# 1   СЗАО             Трикотажная             4.0            3
# 2    САО           Тимирязевская             3.0            3
# 3    ЗАО                    Фили             5.0            3
# 4    САО             Белорусская             4.0            3
# 5   СЗАО                Терехово             1.0            3
# 6    NaN                     NaN             NaN            0
# 7    САО           Тимирязевская             3.0            3
# 8   ЮЗАО      Ленинский проспект            13.0            3
# 9    САО             Белорусская             7.0            3
#
#            Застройщик                                                 ЖК  \
# 0     Компания Пионер                                    «PRIDE (Прайд)»
# 1         СК Резиденс                                      «ÁLIA (АЛИЯ)»
# 2            MR Group                         «SYMPHONY 34 (Симфони 34)»
# 3    Аеон Девелопмент  «River Park Towers Кутузовский (Ривер Парк Тау...
# 4            MR Group              «Комплекс апартаментов Slava (Слава)»
# 5                 NaN                                           «Остров»
# 6                 NaN                                                NaN
# 7            MR Group                         «SYMPHONY 34 (Симфони 34)»
# 8  Hutton Development                                    «Lunar (Лунар)»
# 9              GloraX  «Глоракс Премиум Белорусская (GloraX Premium Б...
#
#      Класс Тип квартиры  Этаж  Этажей в доме       Отделка  Количество комнат  \
# 0  Премиум     квартира   5.0           22.0   Без отделки                1.0
# 1   Бизнес     квартира   2.0           26.0    Неизвестно                1.0
# 2  Премиум     квартира   2.0           36.0      Чистовая                1.0
# 3  Премиум     квартира   2.0           45.0   Без отделки                1.0
# 4  Премиум  апартаменты   2.0           16.0  Предчистовая                1.0
# 5      NaN     квартира   6.0           19.0   Без отделки                1.0
# 6      NaN          NaN   NaN            NaN           NaN                NaN
# 7  Премиум     квартира   8.0           43.0  Предчистовая                3.0
# 8  Премиум  апартаменты   5.0            8.0      Чистовая                1.0
# 9  Премиум  апартаменты   5.0           21.0    Неизвестно                2.0
#
#    Площадь квартиры  Жилая площадь  Площадь кухни  \
# 0             32.20            NaN            NaN
# 1             48.06            NaN            NaN
# 2             37.62           12.8            3.1
# 3             42.80            NaN            NaN
# 4             47.90            NaN            NaN
# 5             44.90           13.5           18.4
# 6               NaN            NaN            NaN
# 7             85.13           33.9            6.2
# 8             48.73           12.5           22.8
# 9             77.85           30.5           27.1
#
#                           Тип дома             Парковка  Год сдачи        Цена
# 0                       Монолитный            Подземная     2025.0  16 106 665
# 1              Монолитно-кирпичный  Подземная, гостевая     2023.0  16 122 800
# 2                       Монолитный  Подземная, гостевая     2025.0  18 472 662
# 3              Монолитно-кирпичный            Подземная     2026.0  22 450 632
# 4              Монолитно-кирпичный  Подземная, гостевая     2023.0  25 160 002
# 5                              NaN                  NaN     2025.0  25 606 470
# 6                              NaN                  NaN        NaN         NaN
# 7                       Монолитный  Подземная, гостевая     2025.0  30 781 218
# 8  Монолитно-кирпичный, монолитный            Подземная     2023.0  31 000 000
# 9                       Монолитный  Подземная, гостевая     2024.0  34 069 999

# %%
df.shape
# Out:
# (1356, 19)

# %% [markdown]
# ### Проверим модель на наличие дубликатов

# %%
df_without_duplicates = df.drop_duplicates()

# %%
df_without_duplicates.shape
# Out:
# (1101, 19)

# %% [markdown]
# В данных было найдено больше 200 дубликатов, что может негативно повлиять на качество модели. Вот почему их необходимо удалить.

# %% [markdown]
# ### Теперь посмотри есть ли пустые строки

# %%
df_without_duplicates[df_without_duplicates['Цена'].notna() == False]
# Out:
#   Округ Ближайшая станция метро  Время до метро  Метро рядом Застройщик   ЖК  \
# 6   NaN                     NaN             NaN            0        NaN  NaN
#
#   Класс Тип квартиры  Этаж  Этажей в доме Отделка  Количество комнат  \
# 6   NaN          NaN   NaN            NaN     NaN                NaN
#
#    Площадь квартиры  Жилая площадь  Площадь кухни Тип дома Парковка  \
# 6               NaN            NaN            NaN      NaN      NaN
#
#    Год сдачи Цена
# 6        NaN  NaN

# %% [markdown]
# Мы видим, что пустых строк было гораздо больше, но их приняли за дубликаты и удалили, что значительно упрощает нашу задачу.
#
# Нам необходимо удалить лишь одну пустую строку.

# %%
df_full = df_without_duplicates[df_without_duplicates['Цена'].notna() == True]

# %%
df_full.shape
# Out:
# (1100, 19)

# %% [markdown]
# ### Информативность признаков

# %% [markdown]
# Следующим шагом выясним, есть ли в модели признаки, информация о которых содержится в малом количестве наблюдений, что делает их неинформативными:

# %%
df_full.isnull().mean()
# Out:
# Округ                      0.000000
# Ближайшая станция метро    0.009091
# Время до метро             0.009091
# Метро рядом                0.000000
# Застройщик                 0.085455
# ЖК                         0.015455
# Класс                      0.085455
# Тип квартиры               0.000000
# Этаж                       0.000000
# Этажей в доме              0.000000
# Отделка                    0.000000
# Количество комнат          0.292727
# Площадь квартиры           0.000000
# Жилая площадь              0.180909
# Площадь кухни              0.249091
# Тип дома                   0.085455
# Парковка                   0.085455
# Год сдачи                  0.000000
# Цена                       0.000000
# dtype: float64

# %% [markdown]
# Среди признаков нет таких, где доля пропусков превышала бы 25%, поэтому нет необходимости удалять какой-либо из них.

# %% [markdown]
# ### Распределение целевой переменной

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1100 entries, 0 to 1339
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Округ                    1100 non-null   object
#  1   Ближайшая станция метро  1090 non-null   object
#  2   Время до метро           1090 non-null   float64
#  3   Метро рядом              1100 non-null   int64
#  4   Застройщик               1006 non-null   object
#  5   ЖК                       1083 non-null   object
#  6   Класс                    1006 non-null   object
#  7   Тип квартиры             1100 non-null   object
#  8   Этаж                     1100 non-null   float64
#  9   Этажей в доме            1100 non-null   float64
#  10  Отделка                  1100 non-null   object
#  11  Количество комнат        778 non-null    float64
#  12  Площадь квартиры         1100 non-null   float64
#  13  Жилая площадь            901 non-null    float64
#  14  Площадь кухни            826 non-null    float64
#  15  Тип дома                 1006 non-null   object
#  16  Парковка                 1006 non-null   object
#  17  Год сдачи                1100 non-null   float64
#  18  Цена                     1100 non-null   object
# dtypes: float64(8), int64(1), object(10)
# memory usage: 171.9+ KB

# %% [markdown]
# Целевая переменная имеет тип object — сделаем int:

# %%
price = df_full['Цена'].apply(lambda x: ''.join(x.split()))
len(price.values)
# Out:
# 1100

# %%
df_full['Цена'] = price.values
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_17140/1957584078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_full['Цена'] = price.values

# %%
df_full = df_full.astype({'Цена': np.int64})

# %% [markdown]
# В датасете есть колонка 'Класс'.
# Проанализируем распределение классов и найдем среднюю цену квартиры в каждом из них:

# %%
df_full['Класс'].unique()
# Out:
# array(['Премиум', 'Бизнес', nan, 'Комфорт'], dtype=object)

# %%
print(f'Средняя стоимость квартиры класса премиум: {round(df_full[df_full["Класс"] == "Премиум"]["Цена"].mean())}')
# Out:
# Средняя стоимость квартиры класса премиум: 24613516

# %%
pd.pivot_table(df_full, index = 'Класс', values = 'Цена', aggfunc = [np.mean, min, max])
# Out:
#                  mean      min       max
#                  Цена     Цена      Цена
# Класс
# Бизнес   1.944659e+07  4525404  34882092
# Комфорт  1.041913e+07  4299137  33033000
# Премиум  2.461352e+07  7312380  34620000

# %%
df_full['Класс'].value_counts()
# Out:
# Комфорт    529
# Бизнес     370
# Премиум    107
# Name: Класс, dtype: int64

# %%
df_full['Класс'].isnull().sum()
# Out:
# 94

# %% [markdown]
# Посмотрим на количество уникальных ЖК и застройщиков:

# %%
df_full['ЖК'].unique()
# Out:
# array(['«PRIDE (Прайд)»', '«ÁLIA (АЛИЯ)»', '«SYMPHONY 34 (Симфони 34)»',
#        '«River Park Towers Кутузовский (Ривер Парк Тауэрс Кутузовский)»',
#        '«Комплекс апартаментов Slava (Слава)»', '«Остров»',
#        '«Lunar (Лунар)»',
#        '«Глоракс Премиум Белорусская (GloraX Premium Белорусская)»',
#        '«Famous (Феймос)»', '«Преображенская площадь»',
#        '«Aquatoria (Акватория)»',
#        '«Luzhniki Collection (Коллекция Лужники)»',
#        '«Republic (Репаблик)»', '«Level Причальный (Левел Причальный)»',
#        '«Dream Towers (Дрим Тауэрс)»', '«8 кленов»',
#        '«Level Мичуринский»', '«SOUL (Соул)»', '«Михалковский»',
#        '«Sky Garden (Скай Гарден)»', '«City Bay (Сити Бэй)»',
#        '«Авиатика»', '«Прокшино»', '«Скандинавия»',
#        '«Город-парк Первый Московский»', '«Wellton Gold (Веллтон Голд)»',
#        '«Октябрьское поле»', '«Вереск»', '«Level Бауманская»',
#        '«Дом Достижение»', '«Петровский парк II»', '«Logos (Логос)»',
#        '«Headliner (Хедлайнер)»', '«Level Академическая»',
#        '«Level Южнопортовая»', '«N’ice Loft»', '«Era (Эра)»',
#        '«MainStreet (Мейнстрит)»', '«Ever (Эвер)»',
#        '«HIGH LIFE Летниковская, 11 (Хай Лайф)»',
#        '«Новые Ватутинки. Заречный»', '«Апартаменты Берег Яузы»',
#        '«Вестердам»', '«Ривер Парк Коломенское»', '«Событие»',
#        '«Eniteo (Энитео)»', '«Театральный квартал»', '«VERY (Вери)»',
#        '«Клубный дом Full House»', '«Движение.Говорово Апарт-комплекс»',
#        '«Бунинские кварталы»', '«Южные сады»', '«Павелецкая сити»',
#        '«Интонация»', '«Квартал Некрасовка»',
#        '«Переделкино Ближнее Город-парк»', '«Цветочные поляны»', '«ОМ»',
#        '«iLove (АйЛав)»', '«Portland (Портленд)»', '«Crystal (Кристал)»',
#        '«Клубный город на реке Primavera (Примавера)»',
#        '«West Tower (Апартаменты бизнес-класса) (Вест Тауэр)»',
#        '«Verdi (Верди)»', nan, '«МФК Варшавские ворота»', '«Mod (Мод)»',
#        '«Hill8 (Хилл8)»', '«Level Нагатинская (Левел Нагатинская)»',
#        '«1-й Нагатинский»', '«Зорге 9»', '«Shagal (Шагал)»',
#        '«Nagatino i-Land (Нагатино Ай-Ленд)»', '«Селигер Сити»',
#        '«Hide («Хайд»)»', '«Дзен-кварталы»', '«AHEAD»',
#        '«Апарт-комплекс Легендарный квартал»',
#        '«Новые Ватутинки. Микрорайон Центральный»',
#        '«Сити-комплекс Мята»',
#        '«CULT (Апартаменты премиум-класса) (Культ)»',
#        '«Цветочные поляны ЭкоПарк»', '«Талисман на Рокоссовского»',
#        '«Серебряный фонтан»', '«The Lake (Лейк)»', '«Legacy (Легаси)»',
#        '«Апартаментный комплекс Level Стрешнево (Левел Стрешнево)»',
#        '«Квартал на набережной NOW»', '«Испанские кварталы»', '«СОЮЗ»',
#        '«Архитектор»', '«ONYX Deluxe (ОНИКС Делюкс)»',
#        '«Прайм Парк (Prime Park)»',
#        '«Vernissage (Апартаменты премиум-класса) (Вернисаж)»',
#        '«Новые Ватутинки. Десна»', '«Графика на воде»', '«Сенатор»',
#        '«Sky House (Скай Хаус)»', '«Сити-комплекс Перец»', '«RED7»',
#        '«Никольские луга»', '«Бунинские луга»', '«Новое Очаково»',
#        '«Волжский парк»', '«Сигнальный 16»', '«Сокольнический вал 1»',
#        '«Ютаново»', '«Clementine (Клементин)»',
#        '«Апартаменты Измайловский парк»', '«Михайловский парк»',
#        '«Метрополия»', '«Светлый мир Станция Л»', '«Кронштадтский 14»',
#        '«Holland park (Холланд парк)»', '«Люблинский парк»',
#        '«Дмитровский парк»', '«Полар»', '«Мещерский лес»',
#        '«Первый Ленинградский»', '«Саларьево парк»', '«Митинский лес»',
#        '«Russian Design District (Рашен Дизайн Дистрикт)»',
#        '«Амурский парк»', '«Кронштадтский 9»', '«Перовское 2»',
#        '«Кавказский бульвар 51»', '«Алтуфьевское 53»',
#        '«Второй Нагатинский»', '«Кольская 8»', '«Полярная 25»',
#        '«Бусиновский парк»', '«Большая Академическая 85»',
#        '«WAVE (Вейв)»', '«SELF (Сэлф)»', '«Руставели 14»',
#        '«Академика Павлова»', '«Барклая 6»', '«Открытый парк»',
#        '«Матвеевский парк»', '«Мичуринский парк»',
#        '«Shome (По ул. Кастанаевская 66)»', '«Сердце Столицы»',
#        '«Moments»', '«Sydney City (Сидней Сити)»', '«LIFE-Варшавская»',
#        '«Клубный дом Рублево»', '«Vangarden (Вангарден)»',
#        '«Фестиваль парк-2»', '«Династия»', '«FORST (Форст)»',
#        '«Движение.Тушино»', '«Green park (Грин парк)»',
#        '«Комплекс апартаментов B’aires (Байрес)»', '«Рихард»',
#        '«Зеленая Вертикаль»', '«LES (Лес)»', '«Большая Очаковская 2»',
#        '«Сити-комплекс Амарант»', '«Середневский лес»', '«Западный порт»',
#        '«Новохохловская 15»', '«Красноказарменная 15»', '«Символ»',
#        '«Afi Tower (Афи Тауэр)»', '«Ренессанс»', '«Юнино»',
#        '«Борисоглебское»', '«Зелёный парк»', '«Level Селигерская»',
#        '«Первый Дубровский»', '«Волоколамское 24»',
#        '«Лосиноостровский парк»', '«Римского-Корсакова 11»',
#        '«Nametkin Tower (Наметкин Тауэр)»',
#        '«Stories на Мосфильмовской (Сторис)»'], dtype=object)

# %%
df_full['Застройщик'].unique()
# Out:
# array(['Компания Пионер', 'СК Резиденс', 'MR Group', 'Аеон Девелопмент',
#        nan, 'Hutton Development', 'GloraX', 'ДОНСТРОЙ', 'Wainbridge',
#        'Absolute Premium', 'Forma', 'Level Group', 'Regions Development',
#        'РГ-Девелопмент', 'ГК ФСК', 'Э.К. Девелопмент', 'А101',
#        'Абсолют Недвижимость', 'ГК МИЦ', 'Sminex-Интеко', 'СЗ Логос',
#        'КОРТРОС', 'Колди (Coldy)', 'TEKTA GROUP', 'ГК Основа',
#        'Новые Ватутинки', 'Концерн КРОСТ', 'Sezar Group', 'Мангазея',
#        'Группа Самолет', 'ООО "СЗ "Стадион "Спартак"', 'Ташир', 'Glincom',
#        'СИТИ21', 'Prime Life Development', 'St Michael', 'Группа Эталон',
#        'VOS’HOD', 'GRAVION', '3SGroup', 'Группа Родина',
#        'Optima Development', 'Ziggurat', 'СЗ Звездный', 'ПИК',
#        'Upside Development', 'ГК Новая Жизнь', 'Seven Suns Development',
#        'ДСК-1', 'Группа ЛСР', 'Велесстрой', 'СЗ Универсаль',
#        'СЗ ПРОГРЕСС', 'AFI Development', '494 УНР', 'October Group'],
#       dtype=object)

# %% [markdown]
# Теперь давайте выясним, в каких ЖК продаются квартиры и каких классов:

# %%
builder_class_pivot = pd.pivot_table(df_full, index = 'Застройщик', columns = 'Класс',values = 'ЖК', aggfunc = [len],fill_value = 0 )
builder_class_pivot
# Out:
#                               len
# Класс                      Бизнес Комфорт Премиум
# Застройщик
# 3SGroup                         8       0       0
# 494 УНР                         0       0       1
# AFI Development                 2       0       0
# Absolute Premium                0       0       1
# Forma                          16       0       5
# GRAVION                         0       0       2
# Glincom                         0       0       5
# GloraX                          0       0       3
# Hutton Development              0       0       3
# Level Group                    38      18       0
# MR Group                       39       0      24
# October Group                   1       0       0
# Optima Development              0       0       1
# Prime Life Development          5       0       0
# Regions Development             0       0       2
# Seven Suns Development          0       6       0
# Sezar Group                     8       0       0
# Sminex-Интеко                   0       7       5
# St Michael                      7       0       0
# TEKTA GROUP                    12       0       3
# Upside Development              0       5       0
# VOS’HOD                         0       0       1
# Wainbridge                      2       0       0
# Ziggurat                        0       0       1
# А101                           18      32       0
# Абсолют Недвижимость            0      23       0
# Аеон Девелопмент                4       0       6
# Велесстрой                      4       0       0
# ГК МИЦ                         26       8       0
# ГК Новая Жизнь                  3       0       0
# ГК Основа                      18       0       4
# ГК ФСК                         24      15       0
# Группа ЛСР                      2       0       0
# Группа Родина                   9       0       2
# Группа Самолет                  0       9       0
# Группа Эталон                   7       0       0
# ДОНСТРОЙ                       19       0       0
# ДСК-1                           0       7       0
# КОРТРОС                        11       0       0
# Колди (Coldy)                   6       0       0
# Компания Пионер                 1       0       7
# Концерн КРОСТ                  10       0       4
# Мангазея                        7       0       0
# Новые Ватутинки                 0      20       0
# ООО "СЗ "Стадион "Спартак"      0       0       2
# ПИК                            30     346       0
# РГ-Девелопмент                  7      23       0
# СЗ Звездный                     2       0       0
# СЗ Логос                        0       0       5
# СЗ ПРОГРЕСС                     4       0       0
# СЗ Универсаль                   0       0       8
# СИТИ21                          0       0       4
# СК Резиденс                    16       0       0
# Ташир                           4       0       8
# Э.К. Девелопмент                0      10       0

# %% [markdown]
# Можно заметить, что количество квартир среди застройщиков распределено неравномерно.
#
# Для большей наглядности построим график распределения классов жилья среди застройщиков, где на оси Х у нас будут непосредственные организации, а по оси Y — количесто квартир.

# %%
builder_class_pivot.plot(kind='bar', stacked=True)
plt.suptitle('Распределение классов жилья по застройщикам')
plt.ylabel('Количество квартир')
plt.show()

# %% [markdown]
# Мы видим, что в большинстве случаев количество квартир, построенных застройщиками, варьируется от 0 до ~25, причем среди них преобладает «бизнес» класс.
#
# Однако есть несколько застройщиков, количество квартир которых достигает 26-63 у.е. (Level Group, MR Group, A101, ГК ФСК, ГК МИЦ, РГ-Девелопмент).
# Самое большое количество квартир у ПИКа — больше 350. Можно отметить, что этот застройщик занимается преимущественно квартирами «комфорт» класса.

# %% [markdown]
# ## Описательные статистики

# %% [markdown]
# Для того чтобы иметь чёткое представление о распределении значений в нашем датасете, нам необходимо оценить все доступные числовые данные и получить сводную статистику о них.

# %%
df_full.describe()
# Out:
#        Время до метро  Метро рядом         Этаж  Этажей в доме  \
# count     1090.000000  1100.000000  1100.000000    1100.000000
# mean         5.962385     2.844545    11.086364      24.415455
# std          4.319373     0.431281     8.945431      10.313782
# min          1.000000     0.000000     1.000000       3.000000
# 25%          3.000000     3.000000     3.000000      17.000000
# 50%          5.000000     3.000000     9.000000      23.000000
# 75%          6.000000     3.000000    16.000000      32.000000
# max         31.000000     3.000000    46.000000      69.000000
#
#        Количество комнат  Площадь квартиры  Жилая площадь  Площадь кухни  \
# count         778.000000       1100.000000     901.000000     826.000000
# mean            1.884319         44.706655      20.333629      11.724697
# std             0.851669         20.446706      12.424390       6.422809
# min             1.000000         15.900000       0.300000       1.200000
# 25%             1.000000         27.700000      11.200000       5.700000
# 50%             2.000000         38.700000      14.500000      10.900000
# 75%             2.000000         59.150000      26.500000      16.600000
# max             4.000000        111.860000      76.700000      42.200000
#
#          Год сдачи          Цена
# count  1100.000000  1.100000e+03
# mean   2023.892727  1.528647e+07
# std       1.121930  8.123496e+06
# min    2018.000000  4.299137e+06
# 25%    2023.000000  8.746150e+06
# 50%    2024.000000  1.197466e+07
# 75%    2025.000000  2.122115e+07
# max    2026.000000  3.488209e+07

# %%
df_full.describe(include='object')
# Out:
#                         Округ Ближайшая станция метро Застройщик  \
# count                    1100                    1090       1006
# unique                     13                     129         55
# top      НАО (Новомосковский)             Филатов Луг        ПИК
# freq                      170                      44        376
#
#                           ЖК    Класс Тип квартиры   Отделка    Тип дома  \
# count                   1083     1006         1100      1100        1006
# unique                   174        3            4         7           7
# top     «Второй Нагатинский»  Комфорт     квартира  Чистовая  Монолитный
# freq                      19      529          664       444         618
#
#                    Парковка
# count                  1006
# unique                    8
# top     Подземная, гостевая
# freq                    546

# %% [markdown]
# Далее посчитаем достаточно распространенную величину в вопросах выбора квартиры - __стоимость 1 кв метра__:

# %%
square_metr = df_full['Цена']/df_full['Площадь квартиры']
square_metr
# Out:
# 0       500206.987578
# 1       335472.326259
# 2       491033.014354
# 3       524547.476636
# 4       525261.002088
#             ...
# 1334    298420.054201
# 1335    210755.916031
# 1337    320674.985673
# 1338    210752.003781
# 1339    219573.996063
# Length: 1100, dtype: float64

# %%
plt.hist(square_metr, bins= 100, color = 'mediumpurple')

plt.ylabel('Частота')
plt.xlabel('Стоимость квадратного метра')
plt.suptitle('Распределение стоимости квадратного метра квартир в Москве')

plt.show()

# %% [markdown]
# Полученные значения похожи на график нормального распределения.
#
# Это говорит о том, что в нашей выборке большинство значений близки к среднему, а крайних значений признака не так много, что может послужить доказательством репрезентативности выбранных данных.

# %% [markdown]
# ## Значимость признаков
#
# Выведем матрицу корреляций вещественных призанаков:

# %%
matrix_corr = df_full.corr()
matrix_corr
# Out:
#                    Время до метро  Метро рядом      Этаж  Этажей в доме  \
# Время до метро           1.000000    -0.360479 -0.042797      -0.063846
# Метро рядом             -0.360479     1.000000  0.041691      -0.020243
# Этаж                    -0.042797     0.041691  1.000000       0.429789
# Этажей в доме           -0.063846    -0.020243  0.429789       1.000000
# Количество комнат       -0.053919    -0.009478 -0.038730      -0.023342
# Площадь квартиры        -0.004625    -0.098936 -0.037154       0.007487
# Жилая площадь            0.009323    -0.092236 -0.078319      -0.035699
# Площадь кухни            0.031573    -0.046983 -0.014642       0.007162
# Год сдачи               -0.038732     0.146034 -0.054925       0.188412
# Цена                     0.001791    -0.150702  0.013511       0.121086
#
#                    Количество комнат  Площадь квартиры  Жилая площадь  \
# Время до метро             -0.053919         -0.004625       0.009323
# Метро рядом                -0.009478         -0.098936      -0.092236
# Этаж                       -0.038730         -0.037154      -0.078319
# Этажей в доме              -0.023342          0.007487      -0.035699
# Количество комнат           1.000000          0.836287       0.869039
# Площадь квартиры            0.836287          1.000000       0.887300
# Жилая площадь               0.869039          0.887300       1.000000
# Площадь кухни               0.054872          0.574955       0.228951
# Год сдачи                  -0.079241         -0.200601      -0.269351
# Цена                        0.526577          0.797701       0.691485
#
#                    Площадь кухни  Год сдачи      Цена
# Время до метро          0.031573  -0.038732  0.001791
# Метро рядом            -0.046983   0.146034 -0.150702
# Этаж                   -0.014642  -0.054925  0.013511
# Этажей в доме           0.007162   0.188412  0.121086
# Количество комнат       0.054872  -0.079241  0.526577
# Площадь квартиры        0.574955  -0.200601  0.797701
# Жилая площадь           0.228951  -0.269351  0.691485
# Площадь кухни           1.000000  -0.023037  0.429540
# Год сдачи              -0.023037   1.000000 -0.217396
# Цена                    0.429540  -0.217396  1.000000

# %%
sns.heatmap(matrix_corr)
plt.suptitle('Матрица корреляций числовых признаков')
plt.show()

# %%
abs(matrix_corr['Цена']).sort_values()
# Out:
# Время до метро       0.001791
# Этаж                 0.013511
# Этажей в доме        0.121086
# Метро рядом          0.150702
# Год сдачи            0.217396
# Площадь кухни        0.429540
# Количество комнат    0.526577
# Жилая площадь        0.691485
# Площадь квартиры     0.797701
# Цена                 1.000000
# Name: Цена, dtype: float64

# %% [markdown]
# Можно заметить, что самую сильную отрицательную линейную корреляцию с ценой квартиры имеет год её сдачи, т.е. чем ближе срок сдачи, тем выше стоимость.
#
# Самая ярко выраженная положительная линейная зависимость с признаком «Площадь квартиры» — почти 0,8; далее следует значение именно «Жилой площади» (~0,7). Это говорит о том, что в большинстве случаев главной характеристикой, по которой определяется цена квартиры, является её квадратура.
#
# Также стоит отметить, что наименьшее влияние на стоимость оказывает отдаленность квартиры от метро (~0.002).

# %% [markdown]
# ## Работа с пропусками

# %%
X = df_full.iloc[:,:-1]
y = df_full['Цена']

# %%
X.isnull().sum()
# Out:
# Округ                        0
# Ближайшая станция метро     10
# Время до метро              10
# Метро рядом                  0
# Застройщик                  94
# ЖК                          17
# Класс                       94
# Тип квартиры                 0
# Этаж                         0
# Этажей в доме                0
# Отделка                      0
# Количество комнат          322
# Площадь квартиры             0
# Жилая площадь              199
# Площадь кухни              274
# Тип дома                    94
# Парковка                    94
# Год сдачи                    0
# dtype: int64

# %% [markdown]
# Заполним пропуски в категориальных признаках пустыми строками, так как подобная ситуация свидетельствует об отсутствии данных признаков на сайте, откуда производился парсинг (это не говорит, что у конкретной квартиры нет этого признака, она просто не была указана в объявлении).
#
# Заполнять его наиболее часто встречающимся значением относительно опасно, потому что у каждой квартиры достаточно специфические характеристики, заполнение которыми может испортить исследуемую модель. Следовательно, наиболее рациональным будет предложенный нами вариант.
#
# Что же касается вещественных признаков, то их заполним средними значениями.
#
# Кроме того, в рассматриваемом датасете есть признаки, которые могут быть только целыми числами — их заполним медианами.
#
# Таким образом, с помощью всех вышеописанных манипуляций мы сможем сделать нашу модель наиболее полной, при этом не испортив её.

# %%
numeric_data = X.select_dtypes([np.number])

numeric_data_int = numeric_data[['Метро рядом', 'Этаж', 'Этажей в доме', 'Количество комнат','Год сдачи']]
numeric_data_float = numeric_data[['Площадь квартиры', 'Жилая площадь', 'Площадь кухни']]

numeric_data_int_median = numeric_data_int.median()
numeric_data_float_mean = numeric_data_float.mean()

int_features = numeric_data_int.columns
float_features = numeric_data_float.columns

X[int_features] = X[int_features].fillna(numeric_data_int_median)
X[float_features] = X[float_features].fillna(numeric_data_float_mean)

# %%
categorical_features = X.dtypes[X.dtypes == "object"].index

X[categorical_features] = X[categorical_features].fillna('')

# %%
X.isnull().sum()
# Out:
# Округ                       0
# Ближайшая станция метро     0
# Время до метро             10
# Метро рядом                 0
# Застройщик                  0
# ЖК                          0
# Класс                       0
# Тип квартиры                0
# Этаж                        0
# Этажей в доме               0
# Отделка                     0
# Количество комнат           0
# Площадь квартиры            0
# Жилая площадь               0
# Площадь кухни               0
# Тип дома                    0
# Парковка                    0
# Год сдачи                   0
# dtype: int64

# %% [markdown]
# На данном этапе есть небольшой нюанс: исходя из здравого смысла, будет некорректно заполнить, например, пропуски в колонке количество комнат в квартире у студии значением, большим 1.

# %%
X[(X['Количество комнат'] > 1) & (X['Тип квартиры'] == 'Студия')]
# Out:
#       Округ Ближайшая станция метро  Время до метро  Метро рядом  \
# 74      ЗАО                    Фили            10.0            3
# 133    СЗАО             Трикотажная             4.0            3
# 144     САО           Тимирязевская             3.0            3
# 147     ЗАО                 Лужники             3.0            3
# 170     САО         Красный Балтиец             4.0            3
# ...     ...                     ...             ...          ...
# 1306   СЗАО               Тушинская             3.0            3
# 1308    ЗАО    Мичуринский проспект             4.0            2
# 1319    ЗАО             Аминьевская             3.0            2
# 1324   СЗАО           Волоколамская             2.0            3
# 1325    ЗАО         Багратионовская             8.0            3
#
#             Застройщик                                                 ЖК  \
# 74    Аеон Девелопмент  «River Park Towers Кутузовский (Ривер Парк Тау...
# 133        СК Резиденс                                      «ÁLIA (АЛИЯ)»
# 144           MR Group                         «SYMPHONY 34 (Симфони 34)»
# 147           MR Group                                    «Hide («Хайд»)»
# 170                                                         «SOUL (Соул)»
# ...                ...                                                ...
# 1306          MR Group                              «City Bay (Сити Бэй)»
# 1308
# 1319     October Group               «Stories на Мосфильмовской (Сторис)»
# 1324          MR Group                              «City Bay (Сити Бэй)»
# 1325               ПИК                                        «Барклая 6»
#
#         Класс Тип квартиры  Этаж  Этажей в доме       Отделка  \
# 74    Премиум       Студия   3.0           46.0      Черновая
# 133    Бизнес       Студия   3.0           22.0   Без отделки
# 144   Премиум       Студия   2.0           36.0      Чистовая
# 147   Премиум       Студия   6.0           41.0  Предчистовая
# 170                 Студия  13.0           20.0  Предчистовая
# ...       ...          ...   ...            ...           ...
# 1306   Бизнес       Студия  17.0           52.0  Предчистовая
# 1308                Студия  14.0           21.0  Предчистовая
# 1319   Бизнес       Студия   6.0           11.0   Без отделки
# 1324   Бизнес       Студия  42.0           53.0  Предчистовая
# 1325   Бизнес       Студия   2.0           32.0  Предчистовая
#
#       Количество комнат  Площадь квартиры  Жилая площадь  Площадь кухни  \
# 74                  2.0             40.50      20.333629      11.724697
# 133                 2.0             24.00      20.333629      11.724697
# 144                 2.0             26.21      14.600000       3.600000
# 147                 2.0             32.10      20.333629      11.724697
# 170                 2.0             24.40      13.300000       2.300000
# ...                 ...               ...            ...            ...
# 1306                2.0             27.05      16.400000      11.724697
# 1308                2.0             26.80      15.700000       3.600000
# 1319                2.0             22.70      11.700000      11.724697
# 1324                2.0             23.90       0.300000      18.600000
# 1325                2.0             27.80      16.000000       3.900000
#
#                  Тип дома             Парковка  Год сдачи
# 74    Монолитно-кирпичный            Подземная     2026.0
# 133   Монолитно-кирпичный  Подземная, гостевая     2025.0
# 144            Монолитный  Подземная, гостевая     2025.0
# 147   Монолитно-кирпичный  Подземная, гостевая     2023.0
# 170                                                2025.0
# ...                   ...                  ...        ...
# 1306           Монолитный            Подземная     2023.0
# 1308                                               2024.0
# 1319           Монолитный            Подземная     2026.0
# 1324           Монолитный            Подземная     2025.0
# 1325           Монолитный  Подземная, гостевая     2025.0
#
# [269 rows x 18 columns]

# %%
X.loc[(X['Количество комнат'] > 1) & (X['Тип квартиры'] == 'Студия'), 'Количество комнат'] = 1

# %%
X[(X['Количество комнат'] > 1) & (X['Тип квартиры'] == 'Студия')]
# Out:
# Empty DataFrame
# Columns: [Округ, Ближайшая станция метро, Время до метро, Метро рядом, Застройщик, ЖК, Класс, Тип квартиры, Этаж, Этажей в доме, Отделка, Количество комнат, Площадь квартиры, Жилая площадь, Площадь кухни, Тип дома, Парковка, Год сдачи]
# Index: []

# %%
df_without_miss = X.join(y)
df_without_miss
# Out:
#                       Округ Ближайшая станция метро  Время до метро  \
# 0                      СВАО            Марьина роща            17.0
# 1                      СЗАО             Трикотажная             4.0
# 2                       САО           Тимирязевская             3.0
# 3                       ЗАО                    Фили             5.0
# 4                       САО             Белорусская             4.0
# ...                     ...                     ...             ...
# 1334   НАО (Новомосковский)                Ольховая            17.0
# 1335   НАО (Новомосковский)             Рассказовка             2.0
# 1337                   СЗАО                 Спартак             5.0
# 1338                    САО                 Водники            12.0
# 1339                   СЗАО         Пятницкое шоссе             4.0
#
#       Метро рядом            Застройщик  \
# 0               2       Компания Пионер
# 1               3           СК Резиденс
# 2               3              MR Group
# 3               3      Аеон Девелопмент
# 4               3              MR Group
# ...           ...                   ...
# 1334            3         Группа Родина
# 1335            3  Абсолют Недвижимость
# 1337            3                   ПИК
# 1338            3                 ДСК-1
# 1339            3                   ПИК
#
#                                                      ЖК    Класс Тип квартиры  \
# 0                                       «PRIDE (Прайд)»  Премиум     квартира
# 1                                         «ÁLIA (АЛИЯ)»   Бизнес     квартира
# 2                            «SYMPHONY 34 (Симфони 34)»  Премиум     квартира
# 3     «River Park Towers Кутузовский (Ривер Парк Тау...  Премиум     квартира
# 4                 «Комплекс апартаментов Slava (Слава)»  Премиум  апартаменты
# ...                                                 ...      ...          ...
# 1334  «Russian Design District (Рашен Дизайн Дистрикт)»   Бизнес     квартира
# 1335                   «Переделкино Ближнее Город-парк»  Комфорт     квартира
# 1337                      «Holland park (Холланд парк)»  Комфорт     квартира
# 1338                             «Первый Ленинградский»  Комфорт     квартира
# 1339                                    «Митинский лес»  Комфорт     квартира
#
#       Этаж  Этажей в доме       Отделка  Количество комнат  Площадь квартиры  \
# 0      5.0           22.0   Без отделки                1.0             32.20
# 1      2.0           26.0    Неизвестно                1.0             48.06
# 2      2.0           36.0      Чистовая                1.0             37.62
# 3      2.0           45.0   Без отделки                1.0             42.80
# 4      2.0           16.0  Предчистовая                1.0             47.90
# ...    ...            ...           ...                ...               ...
# 1334  12.0           13.0   Без отделки                1.0             36.90
# 1335   1.0            9.0   Без отделки                2.0             52.40
# 1337   2.0           13.0   Без отделки                1.0             34.90
# 1338   2.0           14.0  Предчистовая                2.0             52.90
# 1339   6.0           32.0      Чистовая                2.0             50.80
#
#       Жилая площадь  Площадь кухни               Тип дома  \
# 0         20.333629      11.724697             Монолитный
# 1         20.333629      11.724697    Монолитно-кирпичный
# 2         12.800000       3.100000             Монолитный
# 3         20.333629      11.724697    Монолитно-кирпичный
# 4         20.333629      11.724697    Монолитно-кирпичный
# ...             ...            ...                    ...
# 1334      12.200000      11.400000    Монолитно-кирпичный
# 1335      26.300000      11.724697  Панельный, монолитный
# 1337      10.600000      16.100000             Монолитный
# 1338      25.500000      10.600000              Панельный
# 1339      20.600000      17.900000             Монолитный
#
#                                 Парковка  Год сдачи      Цена
# 0                              Подземная     2025.0  16106665
# 1                    Подземная, гостевая     2023.0  16122800
# 2                    Подземная, гостевая     2025.0  18472662
# 3                              Подземная     2026.0  22450632
# 4                    Подземная, гостевая     2023.0  25160002
# ...                                  ...        ...       ...
# 1334                 Подземная, гостевая     2023.0  11011700
# 1335  Отдельная многоуровневая, гостевая     2025.0  11043610
# 1337                 Подземная, гостевая     2024.0  11191557
# 1338  Отдельная многоуровневая, гостевая     2023.0  11148781
# 1339                            Гостевая     2025.0  11154359
#
# [1100 rows x 19 columns]

# %% [markdown]
# ### Посмотрим на распределение целевой переменной

# %%
plt.hist(y, bins = 100, color = 'seagreen' )
plt.suptitle('Распределение целевой переменной')
plt.xlabel('Стоимость квартиры')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Мы видим, что график распределения целевой переменной очень похож на логонормальное распределение, причём его медиана смещена вправо.
#
# Если рассматривать квартиры в качестве базового актива, то можно сделать вывод о том, что вероятность на рост её стоимости в перспективе будет выше, чем на падание. Соответственно, инвесторам выгоднее "лонговать" такой актив, т.е. совершать покупку с расчетом на его будущий рост.

# %% [markdown]
# ### Визуализация данных

# %% [markdown]
# Для более детального изучения проведем исследование по Административным округам Москвы и сопоставим полученные результаты с помощью графиков.
#
# В первую очередь узнаем, сколько уникальных округов фигурирует в нашей модели.

# %%
df_without_miss['Округ'].nunique()
# Out:
# 13

# %% [markdown]
# Далее найдем количество квартир дороже и дешевле медианного значения в каждом из них. Результаты представим в виде графика:

# %%
target_median = y.median()
y.median()
# Out:
# 11974663.5

# %%
more_expencive_median = df_without_miss[df_without_miss['Цена'] > target_median]
less_expencive_median = df_without_miss[df_without_miss['Цена'] <= target_median]

# %%
more_expencive_okrug_num = more_expencive_median.groupby('Округ')['Цена'].count()
less_expencive_okrug_num = less_expencive_median.groupby('Округ')['Цена'].count()

index_exp = more_expencive_okrug_num.index
index_less = less_expencive_okrug_num.index

exp_values = more_expencive_okrug_num.to_numpy()
less_values = less_expencive_okrug_num.to_numpy()

# %%
plt.figure(figsize=(13,5))

plt.suptitle('Распределение округов среди наблюдений')

plt.subplot(1, 2, 1)
plt.title('Квартиры дороже медианы')
plt.barh(more_expencive_okrug_num.index,more_expencive_okrug_num.to_numpy(),color='mediumpurple')
plt.gca().invert_xaxis()
plt.xticks(np.arange(0,150,25))

plt.subplot(1, 2, 2)
plt.title('Квартиры дешевле медианы')
plt.barh(less_expencive_okrug_num.index,less_expencive_okrug_num.to_numpy(),color='seagreen')
plt.xticks(np.arange(0,150,25))
plt.tick_params(bottom=True,right=True,left=False,labelright=True,labelleft=False)


plt.subplots_adjust(wspace=0.05)

plt.show()

# %% [markdown]
# Можно заметить, что наибольшее число квартир, соимость которых выше медианы, приходится на Северо-Западный административный округ (около 108). Следом за ним с одинаковыми значениями идут ЗАО и САО (~88 квартир).
#
# Что же касается квартир дешевле медианы, то следует выделить Новомосковский административный округ с ~138 квартирами. Далее со значением, меньшим почти в 1,8 раз, идет ЮВАО (около 76).
#
# Интересным фактом является то, что в Красногорске и ЦАО вообще нет квартир дешевле медианы. В ТАО и ЗелАО ситуация прямо противоположная.

# %% [markdown]
# Выявим, от чего в большей степени зависело, будет ли цена квартиры больше или меньше медианного значения:

# %%
fig = plt.figure(dpi=80,figsize=(17,9))
ax = fig.add_subplot(projection = '3d')


mask = df_without_miss['Цена'] > target_median
x1 = df_without_miss['Площадь квартиры'][mask]
y1 = df_without_miss['Жилая площадь'][mask]
z1 = df_without_miss['Площадь кухни'][mask]
ax.scatter(x1,y1,z1,color='mediumpurple',label='Дороже медианы')

mask2 = df_without_miss['Цена'] <= target_median
x2 = df_without_miss['Площадь квартиры'][mask2]
y2 = df_without_miss['Жилая площадь'][mask2]
z2 = df_without_miss['Площадь кухни'][mask2]
ax.scatter(x2,y2,z2,color='seagreen',label='Дешевле медианы')

ax.set_ylabel('Жилая площадь')
ax.set_xlabel('Площадь квартиры')
ax.set_zlabel('Площадь кухни')
plt.legend(title='Стоимость квартиры')

plt.show()

# %% [markdown]
# На графике выше видно, что квартиры, которые дешевле медианного значения цены, распологаются в части с маленькой площадью кухни, квартиры в целом и жилой площади в частности.

# %% [markdown]
# ## Планы на будущее
#
# Мы хотели бы обучить линейную и нелинейную (деревья, может быть бустинг) модели.
# В качестве гипотез мы скорее всего будем брать гипотезы о том, как влияют признаки, на целевую метку и влияют ли вообще

# %% [markdown]
# ## Гипотеза о том, что квартиры на 1 и последнем этаже дешевле

# %% [markdown]
# Существует распространенное мнение, что квартиры на 1 и последнем этажах менее привлекатльны для покупателей. Посмотрим на среднюю стоимость 1-, 2-х, 3-х и 4-х комнатных квартир в зависимости от этажа. Найдем среднюю цену квартиры на 1/последнем этажах и сравним его со средней ценой квартир, расположенных на других этажах.

# %% [markdown]
# Создадим отдельную таблицу для квартир на 1/последнем этажах и таблицу для квартир НЕ на 1/последнем этажах.

# %%
first_last_floor = pd.concat([df_full[df_full['Этаж'] == df_full['Этажей в доме']], df_full[df_full['Этаж'] == 1]])
without_first_last_floor = pd.concat([df_full, first_last_floor]).drop_duplicates(keep=False)

# %% [markdown]
# Визуализируем среднюю стоимость квартир на 4 графиках (1-, 2-х, 3-х, 4-х комнатные квартиры). Для этого создадим словари, в которых ключи отвечают за этажи (первый/последний, НЕ первый/последний, все этажи), а значения - средняя стоимость.

# %%
dict_one_first_last = {'первый или последний этаж': first_last_floor[first_last_floor['Количество комнат'] == 1]['Цена'].mean(),
        'НЕ первый или последний этаж': without_first_last_floor[without_first_last_floor['Количество комнат'] == 1]['Цена'].mean(),
        'все этажи': df_full[df_full['Количество комнат'] == 1]['Цена'].mean()}
dict_two_first_last= {'первый или последний этаж': first_last_floor[first_last_floor['Количество комнат'] == 2]['Цена'].mean(),
        'НЕ первый или последний этаж': without_first_last_floor[without_first_last_floor['Количество комнат'] == 2]['Цена'].mean(),
        'все этажи': df_full[df_full['Количество комнат'] == 2]['Цена'].mean()}
dict_three_first_last= {'первый или последний этаж': first_last_floor[first_last_floor['Количество комнат'] == 3]['Цена'].mean(),
        'НЕ первый или последний этаж': without_first_last_floor[without_first_last_floor['Количество комнат'] == 3]['Цена'].mean(),
        'все этажи': df_full[df_full['Количество комнат'] == 3]['Цена'].mean()}
dict_four_first_last= {'первый или последний этаж': first_last_floor[first_last_floor['Количество комнат'] == 4]['Цена'].mean(),
        'НЕ первый или последний этаж': without_first_last_floor[without_first_last_floor['Количество комнат'] == 4]['Цена'].mean(),
        'все этажи': df_full[df_full['Количество комнат'] == 4]['Цена'].mean()}

# %%
plt.figure(figsize=(20, 10))
plt.subplot(2, 2, 1)
plt.bar(dict_one_first_last.keys(), dict_one_first_last.values(), width = 0.4)
plt.ylabel('Средняя цена, млн')
plt.title('1-комнатная квартира')

plt.subplot(2, 2, 2)
plt.bar(dict_two_first_last.keys(), dict_two_first_last.values(), width = 0.4)
plt.ylabel('Средняя цена, млн')
plt.title('2-комнатная квартира')

plt.subplot(2, 2, 3)
plt.bar(dict_three_first_last.keys(), dict_three_first_last.values(), width = 0.4)
plt.ylabel('Средняя цена, млн')
plt.title('3-комнатная квартира')

plt.subplot(2, 2, 4)
plt.bar(dict_four_first_last.keys(), dict_four_first_last.values(), width = 0.4)
plt.ylabel('Средняя цена, млн')
plt.title('4-комнатная квартира')

plt.subplots_adjust(wspace=0.2)

# %% [markdown]
# Как можно заметить, действительно, в среднем квартиры на 1/последнем этажах дешевле квартир на остальных этажах. Впоследствии мы попробуем проверить эту гипотезу.
