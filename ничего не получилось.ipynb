# %%
conda clean --all
# Out:
# Cache location: /Users/polinadmitrieva/opt/anaconda3/pkgs
# Will remove the following tarballs:
#
# /Users/polinadmitrieva/opt/anaconda3/pkgs
# -----------------------------------------
# conda-verify-3.4.2-py_1.conda                 27 KB
# jupyterlab-3.3.2-pyhd3eb1b0_0.conda          3.6 MB
# argon2-cffi-20.1.0-py39h9ed2024_1.conda       44 KB
# locket-0.2.1-py39hecd8cb5_1.conda             10 KB
# libwebp-base-1.2.0-h9ed2024_0.conda          389 KB
# anaconda-client-1.11.2-py39hecd8cb5_0.conda     142 KB
# llvmlite-0.37.0-py39he4411ff_1.conda         291 KB
# freetype-2.10.4-ha233b18_0.conda             564 KB
# oniguruma-6.9.7.1-h9ed2024_0.conda           216 KB
# mpich-4.1.1-hc226d05_0.conda                23.8 MB
# cffi-1.15.1-py39hc55c11b_0.conda             219 KB
# openjpeg-2.4.0-h66ea3da_0.conda              301 KB
# pyerfa-2.0.0-py39h9ed2024_0.conda            323 KB
# cfitsio-3.470-hee0f690_6.conda               782 KB
# ...

# %%
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 6.5 MB 2.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 384 kB 9.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 8.2 MB/s  eta 0:00:01
# ...

# %%
# !pip3 install PySocks

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import requests
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import lxml

# %%
def checkIP():
    ip = requests.get('http://checkip.dyndns.org').content
    soup = BeautifulSoup(ip, 'html.parser')
    print(soup.find('body').text)

checkIP()
# Out:
# Current IP Address: 91.228.178.74

# %%
import socks
import socket
socks.set_default_proxy(socks.SOCKS5, "localhost", 9150)
socket.socket = socks.socksocket

# %%
checkIP()
# Out:
# Current IP Address: 185.220.101.188

# %%
#https://habr.com/ru/companies/ods/articles/346632/ -- основной источник
url = 'https://realty.ya.ru/moskva_i_moskovskaya_oblast/kupit/kvartira/?newFlat=YES&deliveryDate=FINISHED&priceMax=35000000'
response = requests.get(url, headers={'User-Agent': UserAgent().chrome})
response.encoding = 'utf-8'
response
# Out:
# <Response [200]>

# %%
html = response.content
soup = BeautifulSoup(html, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ### Найдем ссылки на квартиры

# %%
list_flats = soup.find(lambda tag: tag.name == 'a' and tag.get('class') == ['Link Link_js_inited Link_size_m Link_theme_islands SerpItemLink OffersSerpItem__link'])
list_flats

# %%
#html = response.content
#soup = BeautifulSoup(html, 'html.parser')

# %%
#https://ru.stackoverflow.com/questions/1365986/%D0%92%D1%8B%D0%B4%D0%B0%D0%B5%D1%82-%D0%BE%D1%88%D0%B8%D0%B1%D0%BA%D1%83-403-%D0%BF%D1%80%D0%B8-%D0%BF%D0%B0%D1%80%D1%81%D0%B8%D0%BD%D0%B3%D0%B5-%D1%81%D0%B0%D0%B9%D1%82%D0%B0-%D0%BF%D1%80%D0%B8-%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D0%B8-requsets-%D0%B0-%D0%BF%D1%80%D0%B8-selenium-1023

#from selenium import webdriver

#options = webdriver.ChromeOptions()
#options.add_experimental_option("excludeSwitches", ["enable-automation"])
#options.add_experimental_option('useAutomationExtension', False)
#options.add_argument("--disable-blink-features=AutomationControlled")
#driver = webdriver.Chrome(options=options)
#driver.get('https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&from_developer=1&hand_over=1&offer_type=flat&region=-1')
